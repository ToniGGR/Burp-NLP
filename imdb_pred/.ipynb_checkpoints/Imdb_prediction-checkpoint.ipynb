# %% [markdown]
# # IMDB Prediction

# %% [markdown]
# Here we try to predict the IMDB Rating based on the episode descriptions

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from keras.models import Sequential
from keras import layers
import keras
# Out:
# 2025-03-11 22:54:57.087454: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741730097.101461   22152 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741730097.105630   22152 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-11 22:54:57.120003: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Import Description and IMDB Dataset

# %%
PATH_DESCRIPTIONS_CLEAN = "../data/episodes_description.csv"
PATH_IMDB_RATINGS_CLEAN = "../data/episodes.json"


df_descriptions = pd.read_csv(PATH_DESCRIPTIONS_CLEAN)
df_imdb_ratings = pd.read_json(PATH_IMDB_RATINGS_CLEAN , orient="index")

# %% [markdown]
# ### Add Ratings to episode description dataset

# %%
df_descriptions["rating"] = pd.Series(list(df_imdb_ratings["rating"]))
df = df_descriptions
df = df.dropna()
df
# Out:
#     Unnamed: 0                               title  \
# 0            0                               Pilot
# 1            1                       Lawnmower Dog
# 2            2              Anatomy Park (Episode)
# 3            3              M. Night Shaym-Aliens!
# 4            4                Meeseeks and Destroy
# ..         ...                                 ...
# 66          66               Rickfending Your Mort
# 67          67           Wet Kuat Amortican Summer
# 68          68  Rise of the Numbericons: The Movie
# 69          69                     Mort: Ragnarick
# 70          70                        Fear No Mort
#
#                                                  text  rating
# 0   middle night obviously drunk rick bursts morty...     7.9
# 1     jerry complains family dog snuffles stupid r...     8.6
# 2   christmas jerry tries enforce idea " human hol...     8.3
# 3   episode opens rick dissecting large rat garage...     8.6
# 4   mr meeseeks existing solve beth ’s problemafte...     9.0
# ..                                                ...     ...
# 66  morty finds rick drunken stupor floor garage s...     7.8
# 67  rick ’s chores ( including cleaning another " ...     6.4
# 68  episode starts exact way post credits scene " ...     4.5
# 69  jerry white void golden light appear front nan...     7.9
# 70    rick morty explore " carnival nightmares " t...     9.4
#
# [71 rows x 4 columns]

# %% [markdown]
# ### Create label for binary classification

# %%
df["evaluation"] = (df["rating"] > 8.2).astype(int)
# Out:
# /tmp/ipykernel_20621/694099369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["evaluation"] = (df["rating"] > 8.2).astype(int)

# %% [markdown]
# ### Label Distribution

# %%
df["evaluation"].value_counts()
# Out:
# evaluation
# 1    36
# 0    35
# Name: count, dtype: int64

# %% [markdown]
# ### Train Test Val Split

# %%
train, test = np.split(df.sample(frac=1), [int(0.8*len(df))])
train
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#     Unnamed: 0                                        title  \
# 65          65                                 Unmortricken
# 35          35                       Rattlestar Ricklactica
# 17          17                Big Trouble in Little Sanchez
# 1            1                                Lawnmower Dog
# 42          42                                 Mortyplicity
# 67          67                    Wet Kuat Amortican Summer
# 62          62                             The Jerrick Trap
# 54          54                                 Night Family
# 6            6                          Raising Gazorpazorp
# 30          30                    The Rickchurian Mortydate
# 23          23                                  Pickle Rick
# 27          27                         The Ricklantis Mixup
# 69          69                              Mort: Ragnarick
# 12          12                               Mortynight Run
# 3            3                       M. Night Shaym-Aliens!
# 49          49                  Forgetting Sarick Mortshall
# 64          64                                That's Amorte
# 43          43                        A Rickconvenient Mort
# 25          25                  The Whirly Dirly Conspiracy
# 9   27 ricks alternate dimensions end murdered res...     9.3           1
# 55  smith family dining panda express discuss next...     8.2           0
# 70    rick morty explore " carnival nightmares " t...     9.4           1
# 14  smith family breakfast jerry ’s older brother ...     9.5           1
# 41  mortally injured rick carried morty escape war...     9.0           1
# 66  morty finds rick drunken stupor floor garage s...     7.8           0
# 46  thanksgiving rick morty break government build...     7.1           0
# 50    rick fully immersed " rick two crows " show ...     9.3           1
# 51  getting stranded remains citadel events previo...     8.5           1
# 0   middle night obviously drunk rick bursts morty...     7.9           0
# 4   mr meeseeks existing solve beth ’s problemafte...     9.0           1
# 48  leaving trip smiths leave rick home alone leav...     8.2           0
# 18  eating pint cherry garcia ice cream actually c...     7.6           0
# 19  flying space rick morty collide interstellar i...     8.5           1
# 40  episode starts version beth leading group gala...     9.0           1
# 5     morty interested jessica lacks opportunity e...     9.1           1
# 26  episode begins school morty hears jessica brok...     8.8           1
# 24  rick morty start garage cleaning multiple worm...     8.1           0
# 34  hoisted petard.after events adventure rick mor...     7.3           0
# 61  episode starts cold open smith family without ...     6.1           0
# 56  morty late school asks rick help arrive time r...     7.8           0
# 52  rick morty summer trip blips chitz goes awry a...     7.8           0
# 36  train zooming space bearded man enters dining ...     8.0           0
# 15  massive alien head appears earth interfering e...     8.2           0
# 63  rick therapy dr wong gets call president curti...     6.8           0
# 57  episode starts recap sequence rick suspects so...     7.8           0
# 13  travelling space jamming music rick morty summ...     8.5           1

# %%
test
# Out:
#     Unnamed: 0                                        title  \
# 35          35                       Rattlestar Ricklactica
# 50          50                               Rickmurai Jack
# 59          59                 A Rick in King Mortur's Mort
# 20          20                       The Wedding Squanchers
# 21          21                   The Rickshank Rickdemption
# 40          40              Star Mort Rickturn of the Jerri
# 54          54                                 Night Family
# 41          41                       Mort Dinner Rick Andre
# 48          48  Rickternal Friendshine of the Spotless Mort
# 58          58                                 Analyze Piss
# 25          25                  The Whirly Dirly Conspiracy
# 69          69                              Mort: Ragnarick
# 56          56                               JuRicksic Mort
# 3            3                       M. Night Shaym-Aliens!
# 7            7                                Rixty Minutes
#
#                                                  text  rating  evaluation
# 35  getting ready adventure rick morty stop talk j...     8.8           1
# 50    rick fully immersed " rick two crows " show ...     9.3           1
# 59  morty drags rick galactic pop restaurant locat...     7.4           0
# 20    rick morty beth summer jerry eating breakfas...     9.3           1
# 21  episode starts rick family sitting booth old f...     9.6           1
# 40  episode starts version beth leading group gala...     9.0           1
# 54    beth trouble falling asleep due jerry ’s sno...     8.5           1
# 41  mortally injured rick carried morty escape war...     9.0           1
# 48  leaving trip smiths leave rick home alone leav...     8.2           0
# 58  somewhat unsuccessful battle mr nimbus rick mo...     8.3           1
# 25  episode begins jerry wallowing lonely new life...     8.4           1
# 69  jerry white void golden light appear front nan...     7.9           0
# 56  morty late school asks rick help arrive time r...     7.8           0
# 3   episode opens rick dissecting large rat garage...     8.6           1
# 7   smith family gathered around television invest...     8.7           1

# %%
test["evaluation"].value_counts()
# Out:
# evaluation
# 1    11
# 0     4
# Name: count, dtype: int64

# %% [markdown]
# ### Create Features and Label for Binary Classification and for Regression

# %%
X_train = train["text"]
X_test = test["text"]

Y_train = train["evaluation"]
Y_test = test["evaluation"]

Y_train_reg = train["rating"] 
Y_test_reg = test["rating"] 


print(Y_test_reg)
# Out:
# 68    4.5
# 20    9.3
# 33    8.2
# 37    8.0
# 45    7.0
# 29    7.9
# 10    8.4
# 28    8.9
# 2     8.3
# 32    8.2
# 31    8.9
# 47    6.3
# 22    8.1
# 8     8.4
# 21    9.6
# Name: rating, dtype: float64

# %% [markdown]
# ### Spacy Pipeline

# %%
import spacy
from spacy.language import Language
from spacy.tokens import Doc

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Remove Lemmatizer to not confuse the model

# %%
nlp.pipeline
nlp.remove_pipe("lemmatizer")
# Out:
# ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7f08bf0f8d00>)

# %% [markdown]
# ### Add Component to lower Doc and Return String

# %%
@Language.component("to_lower")
def custom_to_lower(doc) -> list[str]:
    valid_doc = [token.text.lower()  for token in doc]
    valid_doc_pos = [token.pos_   for token in doc ]

    #return Doc(nlp.vocab , words=valid_doc , pos=valid_doc_pos)
    return valid_doc

# %%
nlp.add_pipe("to_lower", after="ner")
# Out:
# <function __main__.custom_to_lower(doc) -> list[str]>

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f08ca07c700>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7f08ca07d6c0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f0876912c70>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f08bfb1a9c0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f08769112a0>),
#  ('to_lower', <function __main__.custom_to_lower(doc) -> list[str]>)]

# %% [markdown]
# ### Method to tokenize a whole Series of Strings to List of STrings

# %%
def tokenize_list( input_list : pd.Series) -> list:
    return list(nlp.pipe(input_list))

# %% [markdown]
# ## Word2Vec embedding Model

# %% [markdown]
# ### Corpus for all tokens in each text

# %%
corpus = tokenize_list(df["text"])
corpus = [x for x in corpus]

# %%
corpus[1]
# Out:
# ['  ',
#  'jerry',
#  'complains',
#  'family',
#  'dog',
#  'snuffles',
#  'stupid',
#  'rick',
#  'gives',
#  'jerry',
#  'device',
#  'enhances',
#  'dog',
#  '’s',
#  'intelligence',
#  'morty',
#  'go',
#  'dreams',
#  'morty',
#  '’s',
#  'math',
#  'teacher',
#  'persuade',
#  'give',
#  'morty',
#  '"',
#  '"',
#  'class',
#  'morty',
#  'assigned',
#  'less',
#  'homework',
#  'go',
#  'morty',
#  '’s',
#  'math',
#  'teacher',
#  '’s',
#  'dreams',
#  'dreams',
#  'strong',
#  'black',
#  'female',
#  'tv',
#  'character',
#  'named',
#  'mrs',
#  'pancakes',
#  'centaur',
#  '’s',
#  'dreams',
#  'results',
#  'rick',
#  'morty',
#  'eventually',
#  'encountering',
#  'scary',
#  'terry',
#  '(',
#  'parody',
#  'freddy',
#  'krueger',
#  'villain',
#  'ina',
#  'nightmare',
#  'elm',
#  'street',
#  ')',
#  'scary',
#  'terry',
#  'begins',
#  'chasing',
#  'two',
#  'multiple',
#  'dreams',
#  'causing',
#  'rick',
#  'become',
#  'unhinged.at',
#  'one',
#  'point',
#  'two',
#  'come',
#  'across',
#  'dream',
#  'post',
#  'apocalyptic',
#  'city',
#  'decide',
#  'hide',
#  'scary',
#  'terry',
#  'gets',
#  'tired',
#  'scary',
#  'terry',
#  'eventually',
#  'sleeps',
#  'rick',
#  'morty',
#  'enter',
#  'dreams',
#  'quickly',
#  'persuade',
#  'help',
#  'duo',
#  'complete',
#  'mission',
#  'meanwhile',
#  'watching',
#  'several',
#  'exaggerated',
#  'infomercials',
#  'dogs',
#  'snuffles',
#  'builds',
#  'advanced',
#  'mechanical',
#  'suit',
#  'translator',
#  'speak',
#  'humans',
#  'assembles',
#  'robot',
#  'dog',
#  'army',
#  'proceeds',
#  'take',
#  'human',
#  'race',
#  'rick',
#  'finds',
#  'morty',
#  'gives',
#  'pills',
#  'make',
#  'kidneys',
#  'shut',
#  'down.morty',
#  'later',
#  'seen',
#  'lying',
#  'hospital',
#  'bed',
#  'critical',
#  'state',
#  'snuffles',
#  'side',
#  'trying',
#  'keep',
#  'alive',
#  'snuffles',
#  'awakens',
#  '(',
#  'aforementioned',
#  'scenario',
#  'revealed',
#  'dream',
#  ')',
#  'realizes',
#  'colonizing',
#  'earth',
#  'answer',
#  'dog',
#  'kind',
#  'must',
#  'fall',
#  'fate',
#  'humankind',
#  'heartbreak',
#  'cruelty',
#  'snuffles',
#  'morty',
#  'tearful',
#  'goodbye',
#  'snuffles',
#  'leaves',
#  'another',
#  'planet',
#  'intelligent',
#  'dogs',
#  'compassion',
#  'exercised',
#  '"',
#  'pet',
#  'insurance',
#  'mandatory',
#  '"',
#  'after',
#  'credits',
#  'rick',
#  'scary',
#  'terry',
#  'shown',
#  'scary',
#  'class',
#  'taught',
#  'scary',
#  'mr',
#  'johnson',
#  'asks',
#  'called',
#  'scary',
#  'glen',
#  'instead',
#  'fundamentals',
#  'fear',
#  'scary',
#  'glen',
#  'tells',
#  'students',
#  'first',
#  'need',
#  'learn',
#  '"',
#  'chill',
#  '"']

# %% [markdown]
# ### Create Word2Vec Model with All Data

# %%
import gensim
w2v_model = gensim.models.Word2Vec(corpus, min_count=2,
                                 vector_size=100, window=5)

# %% [markdown]
# ### Print All Keys of Model to verify Results

# %%
print(list(w2v_model.wv.key_to_index.keys()))
# Out:
# ['rick', 'morty', '’s', '"', 'jerry', 'beth', 'summer', 'family', 'back', 'time', '(', 'one', 'two', ')', 'get', 'tells', 'however', 'mr', 'planet', 'president', 'asks', 'portal', 'tries', 'go', 'space', 'earth', 'like', 'kill', '’', 'reveals', 'home', 'room', 'find', 'make', 'another', 'ship', 'take', 'people', 'would', 'new', ':', 'away', 'using', 'scene', 'leave', 'garage', 'gets', 'help', 'gun', ';
including', 'onto', 'bar', 'live', 'front', 'power', 'argument', 'let', 'beths', 'thing', 'able', 'transcript', 'unfortunately', 'credit', 'eating', 'top', 'got', 'arm', 'hand', 'lightsaber', 'small', 'trapped', 'fire', 'creatures', 'king', 'turning', 'news', 'falling', 'every', 'pope', 'join', 'enter', 'nothing', 'original', 'kids', 'questions', 'rickbot', 'realize', 'better', 'bad', 'parents', 'woman', 'simply', 'ones', 'force', 'continue', 'captured', 'trio', 'destroyed', 'apologizes', 'alone', 'math', 'sending', 'meet', 'taken', 'crystal', 'forcing', 'hospital', 'technology', 'really', ...

# %% [markdown]
# ### Tesing

# %%
print(w2v_model.wv.similarity('birdperson', 'space'))
# Out:
# 0.99964243

# %%
print(w2v_model.wv["rick"])
# Out:
# [-1.3716506   0.9240154   0.3973449   0.24037056  0.22038226 -1.6828308
#   0.52588546  2.197141   -1.2138851  -0.5750623  -0.54507965 -2.0250783
#   0.15379593  0.35958996  0.18741575 -1.105467    0.36098152 -0.882433
#  -0.43579903 -2.1761734   0.92400557  0.48682472  1.6804049  -0.144995
#   0.36397135 -0.13322356 -1.2255104   0.20168196 -0.6546844   0.04722074
#   1.1385553   0.15228839 -0.1417228  -0.8410199  -0.10115487  1.3933977
#   0.32678345 -0.7056624  -0.87575006 -1.5970784  -0.06006597 -1.2781842
#  -0.76917386  0.20957007  1.1416214  -0.31918663 -1.3687484   0.35260564
#   0.39557517  0.8819806   0.68161434 -1.0296443  -1.0128076  -0.3804097
#  -1.3774831   0.24102195  1.0418468  -0.8833949  -0.9087073   0.33068764
#   0.06500877  0.49202794  0.09310488 -0.41542503 -1.3957956   0.59305054
#   0.3999879   0.8691648  -1.1840428   1.1214616  -0.8924417   0.3662751
#   1.0662941  -0.2883884   1.174044    0.48498452  0.34055567 -0.3149255
#  -0.5092077   0.6047726  -0.85983497 -0.03082056 -0.43212402  0.76646435
#  -0.42055702 -0.22365378  0.86971056  0.45517278  1.103493    0.45304066
#   0.67654085  0.13666819  0.5444139  -0.37885526  2.2884135   0.5560996
#   1.3865854  -1.6145298  -0.0410222   0.31331107]

# %% [markdown]
# ### Method to Calculate Average Vector for a tokenized sentence

# %%
def calculate_average_vector(array , model):
    counter = 0
    vector = np.zeros(shape=(100,))
    for doc in array:
        try:
            vector += np.array(model.wv[doc])
            counter +=1
        except:
            continue
    return vector / counter

# %% [markdown]
# ## Normal Neural Network Classification

# %%
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(100, input_shape=(100,) , activation='relu'))
model.add(Dense(70, activation='relu'))
model.add(Dense(70, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ### Embedd All Train Descriptions

# %%
embedded_x_train : list = []


for x_data in X_train:
    corpus = tokenize_list([x_data])
    corpus = [str(x) for x in corpus]
    embedded_x_train.append(calculate_average_vector(corpus[0] , w2v_model))

embedded_x_train
# Out:
# [array([-0.09959301,  0.05949096,  0.03617109,  0.02389543,  0.0186769 ,
#         -0.12773134,  0.02962757,  0.17047391, -0.09016602, -0.04659812,
#          0.06128536,  0.01999747, -0.00638468, -0.05734098,  0.00503148,
#          0.08526497,  0.03558282, -0.04999125, -0.04624881, -0.0948812 ,
#         -0.01093904, -0.07720791, -0.03424407,  0.01295904,  0.05515629,
#         -0.01953113, -0.08079812,  0.01937302,  0.00844686,  0.04802864,
#          0.0585364 , -0.05844243, -0.07006484, -0.01736144, -0.07152535,
#          0.01567908,  0.04116494, -0.0515318 , -0.06714949,  0.02008051,
#          0.01425094,  0.03930514,  0.00434638, -0.02180298, -0.0846472 ,
#          0.0539012 ,  0.03591972,  0.0411027 , -0.07273424,  0.07510478,
#         -0.04955577,  0.01213784,  0.06004623, -0.03063181,  0.08611296,
#          0.02181481,  0.02832673, -0.02146517, -0.01809403,  0.03720818,
#         -0.05247719,  0.00174217, -0.02917483,  0.04662964, -0.04361936,
#         -0.01591837,  0.05366797,  0.01697985,  0.08573187,  0.02242237,
#          0.04660424,  0.00554572,  0.04292895, -0.0249526 ,  0.13665464,
#          0.02914129,  0.08333859, -0.08878304, -0.00615422,  0.04350399]),
#  array([-0.07774785,  0.04590431,  0.0302542 ,  0.01789423,  0.01506429,
#         -0.10129469,  0.0227948 ,  0.13619236, -0.07171231, -0.03484122,
#         -0.03029279, -0.11632011,  0.01124635,  0.01803193,  0.02114189,
#         -0.06967407,  0.02032313, -0.04379562, -0.02864518, -0.13504786,
#          0.05855458,  0.02340799,  0.08011925, -0.00592455,  0.03221359,
#         -0.01974352, -0.06871854,  0.00121422, -0.04370466, -0.00474624,
#          0.05493469,  0.01943919, -0.00501662, -0.05278538,  0.00322558,
#          0.07703168,  0.032841  , -0.0452781 , -0.04342054, -0.08664311,
#         -0.00829435, -0.07230225, -0.0325784 ,  0.01107656,  0.04875636,
#         -0.01804471, -0.07523359,  0.01513628,  0.00792153,  0.04460423,
#          0.05094486, -0.05506631, -0.06280944, -0.01441495, -0.06666315,
#          0.01395474,  0.03679883, -0.04570909, -0.0612542 ,  0.01796602,
#          0.01173728,  0.03835033,  0.00462691, -0.01827467, -0.07553635,
#          0.05074046,  0.03118354,  0.03706304, -0.06719444,  0.06947967,
#         -0.04645893,  0.00996017,  0.05591968, -0.02858298,  0.07612131,
#          0.01890457,  0.02428847, -0.01973933, -0.01626638,  0.03266873,
#         -0.0450448 ,  0.00393368, -0.02525541,  0.04294949, -0.03914224,
#         -0.01366986,  0.0471159 ,  0.01392592,  0.07912637,  0.02212722,
#          0.04381564,  0.00353886,  0.03817243, -0.02378046,  0.12362861,
#          0.02697595,  0.07558979, -0.07964102, -0.00636197,  0.04057564])]

# %% [markdown]
# ### Fit Model

# %%
model.fit(np.array(embedded_x_train), np.array(Y_train), epochs=250, batch_size=10)
# Out:
# Epoch 1/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4511 - loss: 0.6962
# Epoch 2/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5251 - loss: 0.6932
# Epoch 3/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4794 - loss: 0.6942
# Epoch 4/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5449 - loss: 0.6920
# Epoch 5/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5484 - loss: 0.6911
# Epoch 6/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4941 - loss: 0.6938
# Epoch 7/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4908 - loss: 0.6938
# Epoch 8/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6215 - loss: 0.6588
# Epoch 218/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6501 - loss: 0.6690
# Epoch 219/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5095 - loss: 0.6839
# Epoch 220/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5580 - loss: 0.6724
# Epoch 221/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5270 - loss: 0.6718
# Epoch 222/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5171 - loss: 0.6798
# Epoch 223/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4815 - loss: 0.6730
# Epoch 224/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5793 - loss: 0.6620
# Epoch 225/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4940 - loss: 0.6878
# Epoch 226/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5108 - loss: 0.6882
# Epoch 227/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5504 - loss: 0.6699
# Epoch 228/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6267 - loss: 0.6506
# Epoch 229/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6041 - loss: 0.6715
# Epoch 230/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5399 - loss: 0.6812
# Epoch 231/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5203 - loss: 0.6832
# Epoch 232/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4615 - loss: 0.6807
# Epoch 233/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5778 - loss: 0.6461
# Epoch 234/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5957 - loss: 0.6484
# Epoch 235/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5958 - loss: 0.6554
# Epoch 236/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5456 - loss: 0.6805
# Epoch 237/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5835 - loss: 0.6596
# Epoch 238/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5870 - loss: 0.6787
# Epoch 239/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5850 - loss: 0.6826
# Epoch 240/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5406 - loss: 0.6775
# Epoch 241/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5418 - loss: 0.6744
# Epoch 242/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5731 - loss: 0.6470
# Epoch 243/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5516 - loss: 0.6731
# Epoch 244/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5315 - loss: 0.6871
# Epoch 245/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6116 - loss: 0.6412
# Epoch 246/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5219 - loss: 0.6719
# Epoch 247/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6017 - loss: 0.6471
# Epoch 248/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5040 - loss: 0.6879
# Epoch 249/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5659 - loss: 0.6618
# Epoch 250/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5766 - loss: 0.6813

# %% [markdown]
# ### Function that predicts Evaluation by String

# %%
def test_string_model(input_str , model , emb_model):
    docs = tokenize_list([input_str])[0]
    print(docs)
    counter = 0
    vector = np.zeros(shape=(100,))
    avrg_vector = np.zeros(shape=(100,))
    for doc in docs:
        try:
            vector += np.array(emb_model.wv[doc])
            counter +=1

        except:
            continue

    avrg_vector = vector / counter
    
    vector_with_batch = np.expand_dims(avrg_vector, axis=0)
    
    return model.predict(vector_with_batch)

# %% [markdown]
# ### test Function

# %%
test_string_model("pickle rick is president of the planet" , model , w2v_model)
# Out:
# ['pickle', 'rick', 'is', 'president', 'of', 'the', 'planet']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# array([[0.02056235]], dtype=float32)

# %%
embedded_x_test : list = []

for x_data in X_test:
    corpus = tokenize_list([x_data])
    corpus = [str(x) for x in corpus]
    embedded_x_test.append(calculate_average_vector(corpus[0] , w2v_model))

embedded_x_test
# Out:
# [array([-0.12440885,  0.07411413,  0.04387404,  0.0295455 ,  0.02425495,
#         -0.15675949,  0.03620372,  0.21208523, -0.11143766, -0.05785794,
#         -0.04778468, -0.18567655,  0.01755091,  0.03295935,  0.03318287,
#         -0.11169469,  0.03096293, -0.07036416, -0.04166053, -0.20768823,
#          0.08926805,  0.03562362,  0.13190042, -0.01072643,  0.0458293 ,
#         -0.02812572, -0.10925847,  0.00477629, -0.07158257, -0.00430098,
#          0.08996448,  0.02593161, -0.00733757, -0.08016521,  0.00651263,
#          0.12353416,  0.04726112, -0.07266901, -0.06663986, -0.13749842,
#         -0.01430786, -0.11130294, -0.0510005 ,  0.01596981,  0.08170585,
#         -0.02655312, -0.11881455,  0.02800154,  0.01326847,  0.07237702,
#          0.08419527, -0.08431122, -0.10218437, -0.02926038, -0.10560946,
#          0.0239369 ,  0.06409722, -0.07727618, -0.09814723,  0.03072131,
#          0.02088685,  0.05884275,  0.00481477, -0.03321036, -0.1215769 ,
#          0.07866044,  0.05022351,  0.06358502, -0.10398115,  0.10498669,
#         -0.0745277 ,  0.01652996,  0.08620509, -0.04174899,  0.12448991,
#          0.02928253,  0.03739904, -0.02823276, -0.02707921,  0.05425172,
#         -0.07412639,  0.00466963, -0.0415144 ,  0.06629142, -0.06200025,
#         -0.02510806,  0.07889354,  0.02877815,  0.12617989,  0.03125458,
#          0.06766711,  0.01131871,  0.06127266, -0.03650387,  0.20115565,
#          0.03919329,  0.11784477, -0.13227117, -0.00882444,  0.05896721])]

# %%
model.evaluate(np.array(embedded_x_test), np.array(Y_test), return_dict=True )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.3333 - loss: 0.7205
# {'accuracy': 0.3333333432674408, 'loss': 0.720511257648468}

# %% [markdown]
# ### Perform CV

# %%
from sklearn.model_selection import KFold
X = df["text"]
Y = df["evaluation"]

kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-Fold Cross Validation
val_scores = []
epochs = 10


for train_idx, val_idx in kf.split(X):
    # Daten aufteilen
    x_train, x_val = X[train_idx], X[val_idx]
    y_train, y_val = Y[train_idx], Y[val_idx]
    epochs += 25    

    model = Sequential()
    model.add(Dense(100, input_shape=(100,) , activation='relu'))
    model.add(Dense(70, activation='relu'))
    model.add(Dense(70, activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


    embedded_x_train_cv = []
    for x_data in x_train:
        corpus = tokenize_list([x_data])
        corpus = [str(x) for x in corpus]
        embedded_x_train_cv.append(calculate_average_vector(corpus[0] , w2v_model))
    
    embedded_x_val_cv = []
    for x_data in x_val:
        corpus = tokenize_list([x_data])
        corpus = [str(x) for x in corpus]
        embedded_x_val_cv.append(calculate_average_vector(corpus[0] , w2v_model))
    
    # Trainieren
    model.fit(np.array(embedded_x_train_cv), np.array(y_train).reshape(-1, 1), epochs=epochs, batch_size=10, verbose=0)

    # Evaluieren
    val_loss, val_acc = model.evaluate(np.array(embedded_x_val_cv), np.array(y_val).reshape(-1, 1), verbose=0)
    val_scores.append(val_acc)

print(f"Durchschnittliche Validierungsgenauigkeit: {np.mean(val_scores):.4f}")
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x7f67247213f0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/weakref.py", line 370, in remove
#     def remove(k, selfref=ref(self)):
# KeyboardInterrupt:
# Hello
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Hello
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Hello
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#
# KeyboardInterrupt

# %%
val_scores
# Out:
# [0.4000000059604645,
#  0.5,
#  0.3571428656578064,
#  0.4285714328289032,
#  0.4285714328289032]

# %% [markdown]
# ### Plot Results

# %%
result_tests = []
temp_x_test_vec = np.zeros(shape=(100,))
for temp_x_test in embedded_x_test:
    
    temp_x_test_vec = np.expand_dims(temp_x_test, axis=0)
    result_tests.append(model.predict(np.array(temp_x_test_vec))[0][0])

result_tests
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [0.45738184,
#  0.47537377,
#  0.4327044,
#  0.435351,
#  0.5201308,
#  0.46589395,
#  0.4819521,
#  0.44520122,
#  0.5232512,
#  0.52820885,
#  0.4568846,
#  0.47730654,
#  0.48755032,
#  0.46528593,
#  0.4525372]

# %%
Y_test
# Out:
# 38    1
# 50    1
# 2     1
# 9     1
# 43    0
# 17    1
# 54    1
# 15    0
# 25    1
# 69    0
# 30    0
# 6     0
# 16    1
# 45    0
# 51    1
# Name: evaluation, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.array(range(len(result_tests))) + 1

colors = ["green" if y==1 else "blue" for y in Y_test] # Green = Good Episode

plt.bar(x_axis, result_tests , color=colors)
plt.title('Test Evaluation Neural Net')
plt.xlabel('Test')
plt.ylabel('Prediction Value')
plt.legend(["Over 8.2"] , ["Under 8.2"])
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: pandas>=1.2 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: pillow>=8 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Beispiel: Wahre Labels und vorhergesagte Labels
y_true = Y_test
y_pred = np.array( [ 1 if x > 0.465 else 0  for x in result_tests]  )

# Konfusionsmatrix berechnen
cm = confusion_matrix(y_true, y_pred)

# Anzeige der Konfusionsmatrix mit seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",xticklabels=["under average","over average"], yticklabels=["under average","over average"])
plt.xlabel("Vorhergesagte Klasse")
plt.ylabel("Tatsächliche Klasse")
plt.title("Konfusionsmatrix")
plt.show()
print(cm)
# Out:
# [[2 4]
#  [4 5]]

# %% [markdown]
# ## LSTM Model Classification

# %% [markdown]
# ### Size of Embedding Vector in w2vmodel

# %%
EMBEDDING_DIM = 100

# %% [markdown]
# ### Embedd a whole sentence function

# %%
MAX_LENGTH = 500
def sentence_to_embedding(sentence , embedding_model):
    temp_embedding_matrix = np.zeros((MAX_LENGTH, EMBEDDING_DIM))  # Leere Matrix für Embeddings
    for i, word in enumerate(sentence[:MAX_LENGTH]):  # Maximal 5 Wörter
        if word in embedding_model.wv:
            temp_embedding_matrix[i] = embedding_model.wv[word]  # Wortvektor einfügen
    return temp_embedding_matrix

# %% [markdown]
# ### Prepare Test and Train Data

# %%
X_train_lstm = [sentence_to_embedding(x , w2v_model) for x in X_train ]
X_test_lstm = [sentence_to_embedding(x , w2v_model) for x in X_test ]

# %% [markdown]
# ### LSTM Model Architecture

# %%
ltsm_model=Sequential()

ltsm_model.add(layers.Masking(mask_value=0.0, input_shape=(MAX_LENGTH, EMBEDDING_DIM)))
ltsm_model.add(layers.LSTM(128,activation='relu',return_sequences=False))
ltsm_model.add(layers.Dropout(0.2))
ltsm_model.add(layers.Dense(70 , activation="sigmoid"))
ltsm_model.add(layers.Dense(50 , activation="sigmoid"))
ltsm_model.add(layers.Dense(1, activation="sigmoid"))
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Compile Model

# %%
ltsm_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### Fit LSTM Model

# %%
ltsm_model.fit(np.array(X_train_lstm), np.array(Y_train).reshape(-1, 1), epochs=40, batch_size=10)
# Out:
# Epoch 1/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0
    input_data = np.expand_dims(embedding_matrix, axis=0)
    
    # Vorhersage mit Modell
    prediction = model.predict(input_data)[0][0]  # Output ist eine 2D-Matrix, daher [0][0]
    
    # In "Positiv" oder "Negativ" umwandeln
    sentiment = "Positiv" if prediction > 0.5 else "Negativ"
    print(f"Satz: '{sentence}' → {sentiment} (Score: {prediction:.4f})")
    return prediction

# %% [markdown]
# ### Test

# %%
predict_sentence_ltsm(w2v_model, str(df[(df["title"] == "The Ricks Must Be Crazy")]["text"]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Satz: '16    rick morty summer exit theater showcasing ball...
# Name: text, dtype: object' → Negativ (Score: 0.2859)
# 0.28587362

# %% [markdown]
# ### Plot Test Results

# %%
test_results_lstm_class = []

for title in test["title"]:
    test_results_lstm_class.append(predict_sentence_ltsm(w2v_model, str(df[(df["title"] == title)]["text"])))
for rating in test["evaluation"]:
    print(rating)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Satz: '38    rick morty travel factory flight morty mention...
# Name: text, dtype: object' → Negativ (Score: 0.2695)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Satz: '50      rick fully immersed " rick two crows " show ...
# Name: text, dtype: object' → Negativ (Score: 0.2291)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Satz: '2    christmas jerry tries enforce idea " human hol...
# Name: text, dtype: object' → Negativ (Score: 0.3244)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Satz: '9    27 ricks alternate dimensions end murdered res...
# Name: text, dtype: object' → Positiv (Score: 0.5069)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Satz: '43    buying custom shirts rick morty assaulted acid...
# Name: text, dtype: object' → Negativ (Score: 0.3281)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Satz: '17    eating breakfast jerry asks children summer mo...
# Name: text, dtype: object' → Negativ (Score: 0.3230)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Satz: '54      beth trouble falling asleep due jerry ’s sno...
# Name: text, dtype: object' → Negativ (Score: 0.2892)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Satz: '15    massive alien head appears earth interfering e...
# Name: text, dtype: object' → Negativ (Score: 0.4291)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Satz: '25    episode begins jerry wallowing lonely new life...
# Name: text, dtype: object' → Negativ (Score: 0.3591)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Satz: '69    jerry white void golden light appear front nan...
# Name: text, dtype: object' → Positiv (Score: 0.5039)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Satz: '30    unknown monster attacks janitor tunnels white ...
# Name: text, dtype: object' → Positiv (Score: 0.5421)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Satz: '6    rick haggles owner intergalactic pawn shop mor...
# Name: text, dtype: object' → Negativ (Score: 0.4668)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Satz: '16    rick morty summer exit theater showcasing ball...
# Name: text, dtype: object' → Negativ (Score: 0.2859)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Satz: '45      beth asks jerry watch morty summer due incre...
# Name: text, dtype: object' → Negativ (Score: 0.2421)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Satz: '51    getting stranded remains citadel events previo...
# Name: text, dtype: object' → Positiv (Score: 0.5123)
# 1
# 1
# 1
# 1
# 0
# 1
# 1
# 0
# 1
# 0
# 0
# 0
# 1
# 0
# 1

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.array(range(len(test_results_lstm_class))) + 1

colors = ["green" if y==1 else "blue" for y in Y_test] # Green = Good Episode

plt.bar(x_axis, test_results_lstm_class , color=colors)
plt.title('Test Evaluation LSTM')
plt.xlabel('Test')
plt.ylabel('Prediction Value')
plt.legend(["Over 8.2"] , ["Under 8.2"])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Beispiel: Wahre Labels und vorhergesagte Labels
y_true = Y_test
y_pred = np.array( [ 1 if x > 0.35 else 0  for x in test_results_lstm_class]  ) 

# Konfusionsmatrix berechnen
cm = confusion_matrix(y_true, y_pred)


# Anzeige der Konfusionsmatrix mit seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["under average","over average"], yticklabels=["under average","over average"])
plt.xlabel("Predicted Class")
plt.ylabel("Real Class")
plt.title("Konfusionsmatrix")
plt.show()
print(cm)
# Out:
# [[2 4]
#  [6 3]]

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.array(range(len(test_results_lstm_class))) + 1

plt.bar(x_axis, Y_test_reg )
plt.title('Test Evaluation LSTM')
plt.xlabel('Test')
plt.ylabel('Prediction Value')
plt.show()

# %% [markdown]
# ## Regression with LSTM

# %% [markdown]
# ### Create Embedding Matrix

# %%
VOCAB_SIZE = len(w2v_model.wv.key_to_index.keys()) + 1  # +1 für Padding-Token
EMBEDDING_DIM = 100
embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_DIM))

for word in w2v_model.wv.key_to_index:
    if word in w2v_model.wv:
        embedding_matrix[w2v_model.wv.key_to_index[word]] = w2v_model.wv[word]/ np.linalg.norm(w2v_model.wv[word])

# %% [markdown]
# ### Model Architecture

# %%
X_train_lstm = [sentence_to_embedding(x , w2v_model) for x in X_train ]
print(len(X_train_lstm))

embedding_vector_features=45

ltsm_model_reg=Sequential()

ltsm_model_reg.add(layers.Masking(mask_value=0.0, input_shape=(MAX_LENGTH, EMBEDDING_DIM)))

ltsm_model_reg.add(layers.LSTM(128,activation='relu',return_sequences=False))

ltsm_model_reg.add(layers.Dropout(0.4))
ltsm_model_reg.add(layers.Dense(200, activation="relu"))
ltsm_model_reg.add(layers.Dense(60, activation="relu"))
ltsm_model_reg.add(layers.Dense(60, activation="relu"))
ltsm_model_reg.add(layers.Dense(1, activation=None))
# Out:
# 56

# %% [markdown]
# ### Compile Model

# %%
ltsm_model_reg.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-2), metrics=["mean_absolute_error"])

# %%
len(np.array(Y_train_reg).reshape(-1, 1))
# Out:
# 56

# %% [markdown]
# ### Fit Model

# %%
ltsm_model_reg.fit(np.array(X_train_lstm), np.array(Y_train_reg).reshape(-1, 1), epochs=40, batch_size=10)
# Out:
# Epoch 1/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - loss: 305.5997 - mean_absolute_error: 11.7094
# Epoch 2/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: 368.0237 - mean_absolute_error: 12.0066
# Epoch 3/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - loss: 2587.2375 - mean_absolute_error: 18.0265
# Epoch 4/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - loss: 5972.1846 - mean_absolute_error: 39.5743
# Epoch 5/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - loss: 153653.5469 - mean_absolute_error: 108.9227
# Epoch 6/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - loss: 133702.0312 - mean_absolute_error: 175.6455
# Epoch 7/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - loss: 21928040.0000 - mean_absolute_error: 1420.4310
# Epoch 8/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - loss: 6817193.0000 - mean_absolute_error: 814.8955
# Epoch 9/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - loss: 3946.7859 - mean_absolute_error: 26.6914
# Epoch 10/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 113.3806 - mean_absolute_error: 9.9958
# Epoch 11/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 59.5269 - mean_absolute_error: 7.2006
# Epoch 12/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 56.2649 - mean_absolute_error: 7.2767
# Epoch 13/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 56.6181 - mean_absolute_error: 7.3158
# Epoch 14/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - loss: 48.9177 - mean_absolute_error: 6.8012
# Epoch 15/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - loss: 46.6927 - mean_absolute_error: 6.5380
# Epoch 16/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - loss: 69.4025 - mean_absolute_error: 6.3469
# Epoch 17/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - loss: 44.7773 - mean_absolute_error: 6.3112
# Epoch 18/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - loss: 41.3454 - mean_absolute_error: 5.4684
# Epoch 19/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - loss: 33.6278 - mean_absolute_error: 5.3710
# Epoch 20/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - loss: 27.0341 - mean_absolute_error: 4.6308
# Epoch 21/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - loss: 24.0426 - mean_absolute_error: 4.2892
# Epoch 22/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - loss: 16.9999 - mean_absolute_error: 3.5313
# Epoch 23/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - loss: 34.7499 - mean_absolute_error: 3.7221
# Epoch 24/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - loss: 15.5068 - mean_absolute_error: 3.5304
# Epoch 25/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - loss: 10.6062 - mean_absolute_error: 2.7419
# Epoch 26/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - loss: 9.6861 - mean_absolute_error: 2.5440
# Epoch 27/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - loss: 4.8764 - mean_absolute_error: 1.8713
# Epoch 28/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - loss: 5.2974 - mean_absolute_error: 1.8208
# Epoch 29/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - loss: 2.9551 - mean_absolute_error: 1.3532
# Epoch 30/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 2.4416 - mean_absolute_error: 1.2845
# Epoch 31/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - loss: 4.0593 - mean_absolute_error: 1.3006
# Epoch 32/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - loss: 3.3230 - mean_absolute_error: 1.4201
# Epoch 33/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - loss: 3.5478 - mean_absolute_error: 1.3629
# Epoch 34/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - loss: 2.0408 - mean_absolute_error: 1.0720
# Epoch 35/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - loss: 1.7327 - mean_absolute_error: 1.0234
# Epoch 36/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - loss: 1.6506 - mean_absolute_error: 1.0869
# Epoch 37/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - loss: 1.7676 - mean_absolute_error: 1.0353
# Epoch 38/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - loss: 1.4667 - mean_absolute_error: 0.9809
# Epoch 39/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - loss: 1.6368 - mean_absolute_error: 0.9260
# Epoch 40/40
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - loss: 2.4104 - mean_absolute_error: 1.1872

# %% [markdown]
# ### Function to Predict Rating based on Sentence

# %%
def predict_sentence_ltsm_reg(word2vec_model, sentence):
    """
    Funktion zur Vorhersage eines Satzes mit dem trainierten LSTM-Modell.
    """
    model = ltsm_model_reg
    words = sentence.lower().split()  # Satz in Wörter umwandeln
    embedding_matrix = np.zeros((MAX_LENGTH, EMBEDDING_DIM))  # Leere Matrix für Embeddings
    
    for i, word in enumerate(words[:MAX_LENGTH]):  # Nur die ersten MAX_LENGTH Wörter nehmen
        word = word.lower()
        if word in word2vec_model.wv:
            embedding_matrix[i] = w2v_model.wv[word]# Wortvektor einfügen

    # In 3D-Form bringen: (1, MAX_LENGTH, EMBEDDING_DIM)
    input_data = np.expand_dims(embedding_matrix, axis=0)
    
    # Vorhersage mit Modell
    prediction = model.predict(input_data)[0][0]  # Output ist eine 2D-Matrix, daher [0][0]
    
    # In "Positiv" oder "Negativ" umwandeln
    print(f"{prediction}")
    return prediction

# %%
test_results_lstm_reg = []

for title in test["title"]:
    test_results_lstm_reg.append((predict_sentence_ltsm_reg(w2v_model, str(df[(df["title"] == title)]["text"]))))
test_results_lstm_reg
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 8.474900245666504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 8.515878677368164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 8.359206199645996
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 8.384444236755371
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 8.3923978805542
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 8.374856948852539
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 9.191776275634766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 8.47243881225586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 8.496171951293945
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 8.555121421813965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 8.343735694885254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 8.164682388305664
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 8.469184875488281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 8.391960144042969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 8.301580429077148
# [8.4749,
#  8.515879,
#  8.359206,
#  8.384444,
#  8.392398,
#  8.374857,
#  9.191776,
#  8.472439,
#  8.496172,
#  8.555121,
#  8.343736,
#  8.164682,
#  8.469185,
#  8.39196,
#  8.30158]

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.array(range(len(test_results_lstm_reg))) + 1
width = 0.4
plt.bar(x_axis - 0.2, test_results_lstm_reg , width=width , color="blue")
plt.bar(x_axis + 0.2 , Y_test_reg, width=width , color="black")
plt.ylim(6,10)
plt.title('Test Evaluation LSTM')
plt.xticks(x_axis)
plt.xlabel('Test')
plt.ylabel('Prediction Value')
plt.legend(["Predicted" , "True"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.array(range(len(test_results_lstm_class))) + 1

plt.bar(x_axis, Y_test_reg )
plt.title('Real Values Evaluation LSTM Reg')
plt.xlabel('Test')
plt.ylabel('Prediction Value')
plt.show()

# %% [markdown]
# ### perform Cross Validation

# %% [markdown]
# Get Epochs

# %%
from sklearn.model_selection import KFold
X = df["text"]
Y = df["evaluation"]

kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-Fold Cross Validation
val_scores = []
epochs = 5

ltsm_model_reg.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-2), metrics=["mean_absolute_error"])

for train_idx, val_idx in kf.split(X):
    # Daten aufteilen
    x_train, x_val = X[train_idx], X[val_idx]
    y_train, y_val = Y[train_idx], Y[val_idx]
    epochs += 10

    X_train_lstm = [sentence_to_embedding(x , w2v_model) for x in x_train ]
    X_val_lstm = [sentence_to_embedding(x , w2v_model) for x in x_val]
    
    embedding_vector_features=45
    
    ltsm_model_reg=Sequential()
    
    ltsm_model_reg.add(layers.Masking(mask_value=0.0, input_shape=(MAX_LENGTH, EMBEDDING_DIM)))
    
    ltsm_model_reg.add(layers.LSTM(128,activation='relu',return_sequences=False))
    
    ltsm_model_reg.add(layers.Dropout(0.4))
    ltsm_model_reg.add(layers.Dense(100, activation="relu"))
    ltsm_model_reg.add(layers.Dense(30, activation="relu"))
    ltsm_model_reg.add(layers.Dense(30, activation="relu"))
    ltsm_model_reg.add(layers.Dense(1, activation=None))


    ltsm_model_reg.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-2), metrics=["mean_absolute_error"])


    # Trainieren
    ltsm_model_reg.fit(np.array(X_train_lstm), np.array(y_train).reshape(-1, 1), epochs=epochs, batch_size=10, verbose=0)

    # Evaluieren
    val_mse, val_mae = ltsm_model_reg.evaluate(np.array(X_val_lstm), np.array(y_val).reshape(-1, 1), verbose=0)
    print("Hello")
    val_scores.append(val_mae)

print(f"Durchschnittliche Validierungsabsoluter Fehler: {np.mean(val_scores):.4f}")
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Hello
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Hello
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Hello
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Hello
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Hello
# Durchschnittliche Validierungsabsoluter Fehler: 0.4772

# %%
print(val_scores)
# Out:
# [0.4550323784351349, 0.4733714461326599, 0.5105956196784973, 0.4369160830974579, 0.50996333360672]

# %%
## Hier noch Chart rein fuer den Validation Fehler und Train fehler

# %% [markdown]
# Get Avrg Error

# %%
from sklearn.model_selection import KFold
X = df["text"]
Y = df["evaluation"]

kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-Fold Cross Validation
val_scores = []
epochs = 40


for train_idx, val_idx in kf.split(X):
    # Daten aufteilen
    x_train, x_val = X[train_idx], X[val_idx]
    y_train, y_val = Y[train_idx], Y[val_idx]   

    X_train_lstm = [sentence_to_embedding(x , w2v_model) for x in x_train ]
    X_val_lstm = [sentence_to_embedding(x , w2v_model) for x in x_val]
    
    embedding_vector_features=45
    
    ltsm_model_reg=Sequential()
    
    ltsm_model_reg.add(layers.Masking(mask_value=0.0, input_shape=(MAX_LENGTH, EMBEDDING_DIM)))
    
    ltsm_model_reg.add(layers.LSTM(128,activation='relu',return_sequences=False))
    
    ltsm_model_reg.add(layers.Dropout(0.4))
    ltsm_model_reg.add(layers.Dense(100, activation="relu"))
    ltsm_model_reg.add(layers.Dense(30, activation="relu"))
    ltsm_model_reg.add(layers.Dense(30, activation="relu"))
    ltsm_model_reg.add(layers.Dense(1, activation=None))


    ltsm_model_reg.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-2), metrics=["mean_absolute_error"])


    # Trainieren
    ltsm_model_reg.fit(np.array(X_train_lstm), np.array(y_train).reshape(-1, 1), epochs=epochs, batch_size=10, verbose=0)

    # Evaluieren
    val_mse, val_mae = ltsm_model_reg.evaluate(np.array(X_val_lstm), np.array(y_val).reshape(-1, 1), verbose=0)
    print("Hello")
    val_scores.append(val_mae)

print(f"Durchschnittliche Validierungsabsoluter Fehler: {np.mean(val_scores):.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.model_selection import KFold
# ----> 2 X = df["text"]
#       3 Y = df["evaluation"]
#       5 kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-Fold Cross Validation
#
# NameError: name 'df' is not defined

# %%
val_scores
# Out:
# [0.4996431767940521,
#  0.4830387234687805,
#  0.5242437124252319,
#  0.4312141239643097,
#  0.49884870648384094]

# %%
predict_sentence_ltsm_reg(w2v_model, str(df[(df["title"] == "JuRicksic Mort")]["text"]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 8.469184875488281
# 8.469185

# %%
predict_sentence_ltsm_reg(w2v_model, "This is a test clause by pickle rick and morty")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 6.826783657073975
# 6.8267837

# %%
ltsm_model_reg.evaluate(np.array(X_test_lstm) , np.array(Y_test_reg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 ltsm_model_reg.evaluate(np.array(X_test_lstm) , np.array(Y_test_reg))
#
# NameError: name 'X_test_lstm' is not defined
