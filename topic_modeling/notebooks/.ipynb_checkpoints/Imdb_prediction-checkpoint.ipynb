# %% [markdown]
# # IMDB Prediction

# %% [markdown]
# Here we try to predict the IMDB Rating based on the episode descriptions

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from keras.models import Sequential
from keras import layers
import keras
# Out:
# 2025-01-29 15:50:24.571942: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738162224.590058   42659 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738162224.595179   42659 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-29 15:50:24.611813: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Import Description and IMDB Dataset

# %%
PATH_DESCRIPTIONS_CLEAN = "/home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/topic_modeling/data/episodes_description.csv"
PATH_IMDB_RATINGS_CLEAN = "/home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/data/episodes.json"


df_descriptions = pd.read_csv(PATH_DESCRIPTIONS_CLEAN)
df_imdb_ratings = pd.read_json(PATH_IMDB_RATINGS_CLEAN , orient="index")
# Out:
# 1     7.9
# 2     8.6
# 3     8.3
# 4     8.6
# 5     9.0
#      ...
# 67    7.8
# 68    6.4
# 69    4.5
# 70    7.9
# 71    9.4
# Name: rating, Length: 71, dtype: float64

# %% [markdown]
# ### Add Ratings to episode description dataset

# %%
df_descriptions["rating"] = pd.Series(list(df_imdb_ratings["rating"]))
df = df_descriptions
df = df.dropna()
# Out:
#     Unnamed: 0                               title  \
# 0            0                               Pilot
# 1            1                       Lawnmower Dog
# 2            2              Anatomy Park (Episode)
# 3            3              M. Night Shaym-Aliens!
# 4            4                Meeseeks and Destroy
# ..         ...                                 ...
# 66          66               Rickfending Your Mort
# 67          67           Wet Kuat Amortican Summer
# 68          68  Rise of the Numbericons: The Movie
# 69          69                     Mort: Ragnarick
# 70          70                        Fear No Mort
#
#                                                  text  rating
# 0   middle night obviously drunk rick bursts morty...     7.9
# 1     jerry complains family dog snuffles stupid r...     8.6
# 2   christmas jerry tries enforce idea " human hol...     8.3
# 3   episode opens rick dissecting large rat garage...     8.6
# 4   mr meeseeks existing solve beth ’s problemafte...     9.0
# ..                                                ...     ...
# 66  morty finds rick drunken stupor floor garage s...     7.8
# 67  rick ’s chores ( including cleaning another " ...     6.4
# 68  episode starts exact way post credits scene " ...     4.5
# 69  jerry white void golden light appear front nan...     7.9
# 70    rick morty explore " carnival nightmares " t...     9.4
#
# [71 rows x 4 columns]

# %% [markdown]
# ### Create label for binary classification

# %%
df["evaluation"] = (df["rating"] > 8.2).astype(int)
# Out:
# /tmp/ipykernel_42659/694099369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["evaluation"] = (df["rating"] > 8.2).astype(int)

# %% [markdown]
# ### Label Distribution

# %%
df["evaluation"].value_counts()
# Out:
# evaluation
# 1    36
# 0    35
# Name: count, dtype: int64

# %% [markdown]
# ### Train Test Val Split

# %%
train, val, test = np.split(df.sample(frac=1), [int(0.8*len(df)), int(0.9*len(df))])
train
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#     Unnamed: 0                                        title  \
# 56          56                               JuRicksic Mort
# 60          60     Ricktional Mortpoon's Rickmas Mortcation
# 37          37                                   Promortyus
# 31          31           Edge of Tomorty: Rick Die Rickpeat
# 51          51                                    Solaricks
# 1            1                                Lawnmower Dog
# 15          15                       Get Schwifty (episode)
# 50          50                               Rickmurai Jack
# 27          27                         The Ricklantis Mixup
# 47          47                Gotron Jerrysis Rickvangelion
# 9            9         Close Rick-Counters of the Rick Kind
# 10    beth jerry leave trip experience titanic 2 r...     8.4           1
# 6   rick haggles owner intergalactic pawn shop mor...     7.9           0
# 29  learning news convicted child murderer joseph ...     7.9           0
# 67  rick ’s chores ( including cleaning another " ...     6.4           0
# 68  episode starts exact way post credits scene " ...     4.5           0
# 45    beth asks jerry watch morty summer due incre...     7.0           0
# 35  getting ready adventure rick morty stop talk j...     8.8           1
# 14  smith family breakfast jerry ’s older brother ...     9.5           1
# 20    rick morty beth summer jerry eating breakfas...     9.3           1
# 36  train zooming space bearded man enters dining ...     8.0           0
# 25  episode begins jerry wallowing lonely new life...     8.4           1
# 21  episode starts rick family sitting booth old f...     9.6           1
# 34  hoisted petard.after events adventure rick mor...     7.3           0
# 54    beth trouble falling asleep due jerry ’s sno...     8.5           1
# 26  episode begins school morty hears jessica brok...     8.8           1
# 49    morty travels dimension dimension cleaning m...     8.2           0
# 62  rick fixing flying saucer garage jerry comes a...     7.3           0
# 42  rick family eating rick tells family god real ...     8.7           1
# 44  beth ’s workplace morty begs hurry miss movie ...     5.7           0
# 46  thanksgiving rick morty break government build...     7.1           0
# 55  smith family dining panda express discuss next...     8.2           0
# 57  episode starts recap sequence rick suspects so...     7.8           0
# 38  rick morty travel factory flight morty mention...     9.5           1
# 43  buying custom shirts rick morty assaulted acid...     7.8           0
# 40  episode starts version beth leading group gala...     9.0           1
# 39  family vacation jerry tries force morty summer...     7.7           0
# 22  jerry wearing rick morty summer fall portal ba...     8.1           0
# 53  following promise “ solaricks ” space beth com...     7.7           0
# 59  morty drags rick galactic pop restaurant locat...     7.4           0
# 12  rick teaching morty drive space cruiser talks ...     8.8           1
# 23  guess needing morty preparing school advised t...     9.3           1

# %%
test["evaluation"].value_counts()
# Out:
# evaluation
# 1    5
# 0    3
# Name: count, dtype: int64

# %%
val["evaluation"].value_counts()
# Out:
# evaluation
# 1    4
# 0    3
# Name: count, dtype: int64

# %% [markdown]
# ### Create Features and Label for Binary Classification and for Regression

# %%
X_train = train["text"]
X_val = val["text"]
X_test = test["text"]

Y_train = train["evaluation"]
Y_val = val["evaluation"]
Y_test = test["evaluation"]

Y_train_reg = train["rating"] * 100
Y_val_reg = val["rating"] * 100
Y_test_reg = test["rating"] * 100


print(Y_test_reg)
# Out:
# 70    940.0
# 5     910.0
# 48    820.0
# 52    780.0
# 3     860.0
# 11    880.0
# 16    930.0
# 63    680.0
# Name: rating, dtype: float64

# %% [markdown]
# ### Spacy Pipeline

# %%
import spacy
from spacy.language import Language
from spacy.tokens import Doc

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Remove Lemmatizer to not confuse the model

# %%
nlp.pipeline
nlp.remove_pipe("lemmatizer")
# Out:
# ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7fbfa1ea3780>)

# %% [markdown]
# ### Add Component to lower Doc and Return String

# %%
@Language.component("to_lower")
def custom_to_lower(doc):
    valid_doc = [token.text.lower()  for token in doc]
    valid_doc_pos = [token.pos_   for token in doc ]

    #return Doc(nlp.vocab , words=valid_doc , pos=valid_doc_pos)
    return valid_doc

# %%
nlp.add_pipe("to_lower", after="ner")
# Out:
# <function __main__.custom_to_lower(doc)>

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7fbfa1e97f40>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7fbfa1e97d00>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7fbee0598ba0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7fbfa1ec2200>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fbee0598c80>),
#  ('to_lower', <function __main__.custom_to_lower(doc)>)]

# %% [markdown]
# ### Method to tokenize a whole Series of Strings to List of STrings

# %%
def tokenize_list( input_list : pd.Series):
    return list(nlp.pipe(input_list))

# %%
# def df_to_dataset(dataframe, shuffle=True, batch_size=1024):
#   df = dataframe.copy()
#   labels = df.pop('evaluation')
#   df = df["text"]
#   ds = tf.data.Dataset.from_tensor_slices((df, labels))
#   if shuffle:
#     ds = ds.shuffle(buffer_size=len(dataframe))
#   ds = ds.batch(batch_size)
#   ds = ds.prefetch(tf.data.AUTOTUNE)
#   return ds

# %%
# train_data = df_to_dataset(train)
# valid_data = df_to_dataset(val)
# test_data = df_to_dataset(test)
# train_data

# %%
# from sklearn.feature_extraction.text import CountVectorizer

# vectorizer = CountVectorizer()
# vectorizer.fit(train["text"])

# X_train = vectorizer.transform(train["text"])
# X_test  = vectorizer.transform(test["text"])
# Y_train = train["evaluation"]
# Y_valid = val["evaluation"]
# Y_test = test["evaluation"]

# %%
# # label encode the target variable 
# encoder = preprocessing.LabelEncoder()
# train_y = encoder.fit_transform(train_y)
# valid_y = encoder.fit_transform(valid_y)

# %% [markdown]
# ## Word2Vec embedding Model

# %% [markdown]
# ### Corpus for all tokens in each text

# %%
corpus = tokenize_list(df["text"])
corpus = [x for x in corpus]

# %%
corpus[1]
# Out:
# ['  ',
#  'jerry',
#  'complains',
#  'family',
#  'dog',
#  'snuffles',
#  'stupid',
#  'rick',
#  'gives',
#  'jerry',
#  'device',
#  'enhances',
#  'dog',
#  '’s',
#  'intelligence',
#  'morty',
#  'go',
#  'dreams',
#  'morty',
#  '’s',
#  'math',
#  'teacher',
#  'persuade',
#  'give',
#  'morty',
#  '"',
#  '"',
#  'class',
#  'morty',
#  'assigned',
#  'less',
#  'homework',
#  'go',
#  'morty',
#  '’s',
#  'math',
#  'teacher',
#  '’s',
#  'dreams',
#  'dreams',
#  'strong',
#  'black',
#  'female',
#  'tv',
#  'character',
#  'named',
#  'mrs',
#  'pancakes',
#  'centaur',
#  '’s',
#  'dreams',
#  'results',
#  'rick',
#  'morty',
#  'eventually',
#  'encountering',
#  'scary',
#  'terry',
#  '(',
#  'parody',
#  'freddy',
#  'krueger',
#  'villain',
#  'ina',
#  'nightmare',
#  'elm',
#  'street',
#  ')',
#  'scary',
#  'terry',
#  'begins',
#  'chasing',
#  'two',
#  'multiple',
#  'dreams',
#  'causing',
#  'rick',
#  'become',
#  'unhinged.at',
#  'one',
#  'point',
#  'two',
#  'come',
#  'across',
#  'dream',
#  'post',
#  'apocalyptic',
#  'city',
#  'decide',
#  'hide',
#  'scary',
#  'terry',
#  'gets',
#  'tired',
#  'scary',
#  'terry',
#  'eventually',
#  'sleeps',
#  'rick',
#  'morty',
#  'enter',
#  'dreams',
#  'quickly',
#  'persuade',
#  'help',
#  'duo',
#  'complete',
#  'mission',
#  'meanwhile',
#  'watching',
#  'several',
#  'exaggerated',
#  'infomercials',
#  'dogs',
#  'snuffles',
#  'builds',
#  'advanced',
#  'mechanical',
#  'suit',
#  'translator',
#  'speak',
#  'humans',
#  'assembles',
#  'robot',
#  'dog',
#  'army',
#  'proceeds',
#  'take',
#  'human',
#  'race',
#  'rick',
#  'finds',
#  'morty',
#  'gives',
#  'pills',
#  'make',
#  'kidneys',
#  'shut',
#  'down.morty',
#  'later',
#  'seen',
#  'lying',
#  'hospital',
#  'bed',
#  'critical',
#  'state',
#  'snuffles',
#  'side',
#  'trying',
#  'keep',
#  'alive',
#  'snuffles',
#  'awakens',
#  '(',
#  'aforementioned',
#  'scenario',
#  'revealed',
#  'dream',
#  ')',
#  'realizes',
#  'colonizing',
#  'earth',
#  'answer',
#  'dog',
#  'kind',
#  'must',
#  'fall',
#  'fate',
#  'humankind',
#  'heartbreak',
#  'cruelty',
#  'snuffles',
#  'morty',
#  'tearful',
#  'goodbye',
#  'snuffles',
#  'leaves',
#  'another',
#  'planet',
#  'intelligent',
#  'dogs',
#  'compassion',
#  'exercised',
#  '"',
#  'pet',
#  'insurance',
#  'mandatory',
#  '"',
#  'after',
#  'credits',
#  'rick',
#  'scary',
#  'terry',
#  'shown',
#  'scary',
#  'class',
#  'taught',
#  'scary',
#  'mr',
#  'johnson',
#  'asks',
#  'called',
#  'scary',
#  'glen',
#  'instead',
#  'fundamentals',
#  'fear',
#  'scary',
#  'glen',
#  'tells',
#  'students',
#  'first',
#  'need',
#  'learn',
#  '"',
#  'chill',
#  '"']

# %% [markdown]
# ### Create Word2Vec Model with All Data

# %%
import gensim
w2v_model = gensim.models.Word2Vec(corpus, min_count=5,
                                 vector_size=100, window=5)

# %% [markdown]
# ### Print All Keys of Model to verify Results

# %%
print(list(w2v_model.wv.key_to_index.keys()))
# Out:
# ['rick', 'morty', '’s', '"', 'jerry', 'beth', 'summer', 'family', 'back', 'time', '(', 'one', 'two', ')', 'get', 'tells', 'however', 'mr', 'planet', 'president', 'asks', 'portal', 'tries', 'go', 'space', 'earth', 'like', 'kill', '’', 'reveals', 'home', 'find', 'room', 'another', 'make', 'take', 'ship', 'people', 'new', 'would', 'away', ':', 'scene', 'using', 'leave', 'garage', 'gets', 'gun', 'help', ';', 'begins', 'smith', 'man', 'explains', 'quickly', 'dimension', 'still', 'goes', 'killing', 'leaves', 'life', 'alien', 'takes', 'snake', 'upon', 'prime', 'way', 'house', 'post', 'fight', 'world', 'first', 'attempts', 'going', 'death', 'ricks', 'episode', 'decides', 'leaving', 'body', 'memory', 'head', 'water', 'killed', 'finds', 'credits', 'causing', 'turns', 'escape', 'hole', 'says', 'birdperson', 'gives', 'also', 'return', 'finally', 'car', 'together', 'use', 'jessica', 'left', 'wants', 'device', 'mind', 'day', 'work', 'around', 'arrives', 'free', 'school', 'even', 'getting', 'fear', 'eventually', 'robot', 'appears', 'citadel', 'show', 'real', 'rest', 'story', 'federation', 'due', 'comes', 'night', 'evil', 'save', 'something', 'trying', 'making', 'try', 'instead', 'adventure', 'starts', 'attempt', 'makes', 'become', 'soon', 'uses', 'claiming', 'could', 'stop', 'much', 'named', 'despite', 'turn', 'entire', 'saying', 'calls', 'idea', 'inside', 'end', 'everyone', 'cop', 'control', 'refuses', 'actually', 'called', 'next', 'becomes', 'outside', 'three', 'come', 'plan', 'poopybutthole', 'unity', 'realizing', 'telling', 'father', 'see', 'various', 'point', 'made', 'though', 'break', 'kills', 'well', 'keep', 'zeep', 'reality', 'clone', 'dr', 'snakes', 'know', 'several', 'later', 'love', 'latter', 'machine', 'tell', 'returns', 'giant', 'never', 'person', 'agrees', 'last', 'sees', 'realizes', 'goldenfold', 'aliens', 'memories', 'arrive', 'party', 'full', 'shows', 'galactic', 'place', 'ends', 'used', 'travel', 'living', 'human', 'run', 'looking', 'tammy', 'give', 'train', 'tony', 'accidentally', 'enters', 'wong', 'shoots', 'spaghetti', 'start', 'promptly', 'dinosaurs', 'suddenly', 'asking', 'set', 'happened', 'wife', 'many', 'leading', 'meeseeks', 'leads', 'orders', 'group', 'since', 'revealed', 'along', 'game', 'guards', 'sun', 'second', 'diane', 'created', 'taking', 'destroy', 'call', 'fortune', 'without', 'revealing', 'adventures', 'die', 'version', 'immediately', 'giving', 'old', 'fighting', 'seen', 'offers', 'sex', 'knights', 'admits', 'relationship', 'ever', 'turkey', 'self', 'behind', 'order', 'across', 'mortys', 'app', 'ice', 'fly', 'things', 'view', 'manages', 'put', 'good', 'decide', 'runs', 'suggests', 'looks', 'begin', 'causes', 'council', 'whole', 'fact', 'vindicators', 'universe', 'glootie', 'bigfoot', 'part', 'leader', 'talking', 'falls', 'kuato', 'watch', 'brain', 'enough', 'box', 'notices', 'watching', 'suit', 'meanwhile', 'responds', 'fluid', 'ultimately', 'ground', 'team', 'page', 'serum', 'son', 'long', 'others', 'attack', 'seeing', 'high', 'pulls', 'look', 'open', 'nimbus', 'side', 'sperm', 'cat', 'shot', 'door', 'wanted', 'jr', 'talk', 'need', 'points', 'mother', 'opens', 'stay', 'children', 'friend', 'crew', 'tree', 'therapy', 'battle', 'continues', 'gallery', 'toxic', 'someone', 'face', 'shoot', 'dead', 'alive', 'plans', 'beths', 'air', 'following', 'live', 'towards', 'actions', 'power', 'creature', 'ask', 'thing', 'let', 'suicide', 'including', 'able', 'credit', 'bar', 'onto', 'best', 'unfortunately', 'transcript', 'robots', 'state', 'energy', 'front', 'argument', 'king', 'nothing', 'trapped', 'lightsaber', 'every', 'rickbot', 'original', 'falling', 'top', 'realize', 'pope', 'join', 'kids', 'arm', 'got', 'questions', 'news', 'eating', 'fire', 'turning', 'creatures', 'small', 'hand', 'better', 'enter', 'ones', 'discover', 'really', 'bad', '.click', 'captured', 'alone', 'simply', 'trio', 'parents', 'alternate', 'secret', 'destroyed', 'sending', 'care', 'continue', 'different', 'future', 'forcing', 'hospital', 'time ...

# %% [markdown]
# ### Tesing

# %%
print(w2v_model.wv.similarity('birdperson', 'planet'))
# Out:
# 0.9997021

# %%
print(w2v_model.wv["rick"])
# Out:
# [-0.727202    0.62608945 -0.1386765   0.36537522  0.0585373  -0.9544966
#   0.05284276  1.3044839  -0.28951487 -0.5478123  -0.25373077 -0.9001071
#  -0.17683557  0.4536273   0.35818505 -0.46485695  0.09589595 -0.47621137
#  -0.21946847 -1.1508756   0.7980473   0.75792724  0.44852173 -0.3113449
#  -0.23688167 -0.15163186 -0.9829633  -0.52889484 -0.56268424  0.2082649
#   1.0506023   0.06553474  0.20429268 -0.8318434  -0.1859098   0.70889425
#  -0.25388512 -0.77442485 -0.51421005 -0.85655415  0.5625726  -0.8074664
#  -0.47160897 -0.08017732  0.6685002  -0.40894485 -0.10854598 -0.32836592
#   0.5208163   0.359428    0.54980767 -0.68031996 -0.90321827 -0.55596274
#  -0.5002239   0.3300627   0.56145513  0.10184269 -0.71380335  0.69366866
#   0.37864023  0.39290017  0.16622724 -0.36072493 -0.73252916  0.87373006
#   0.5733215   0.41138947 -0.9349678   0.91201633 -0.16686253  0.404694
#   0.8593446  -0.3032137   0.98320585  0.13456495  0.19780286  0.10214608
#  -0.40568897  0.01089427 -0.555665   -0.00437387 -0.50471795  0.7431212
#  -0.04579004  0.00547987  0.52266765  0.20742825  0.7729882  -0.09038156
#   0.8355787   0.3297686   0.37456197 -0.00546129  1.4742818   0.9091753
#   0.65320075 -0.8589643   0.34611878 -0.1010442 ]

# %% [markdown]
# ### Method to Calculate Average Vector for a tokenized sentence

# %%
def calculate_average_vector(array , model):
    counter = 0
    vector = np.zeros(shape=(100,))
    for doc in array:
        try:
            vector += np.array(model.wv[doc])
            counter +=1
        except:
            continue
    return vector / counter

# %% [markdown]
# ## Normal Neural Network Classification

# %%
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(100, input_shape=(100,) , activation='relu'))
model.add(Dense(70, activation='relu'))
model.add(Dense(70, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-01-29 15:50:32.263317: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ### Embedd All Train Descriptions

# %%
embedded_x_train = []


for x_data in X_train:
    corpus = tokenize_list([x_data])
    corpus = [str(x) for x in corpus]
    embedded_x_train.append(calculate_average_vector(corpus[0] , w2v_model))

embedded_x_train
# Out:
# [array([-0.16009254,  0.13286437, -0.03073573,  0.07860217,  0.01774951,
#         -0.19627577,  0.00350824,  0.26739219, -0.06276883, -0.11629569,
#         -0.04968518, -0.18848278, -0.03885357,  0.08774078,  0.07619349,
#         -0.10378878,  0.02924772, -0.10242294, -0.04391629, -0.24286667,
#          0.1621238 ,  0.15561845,  0.09571472, -0.0671634 , -0.05367709,
#          0.21015407, -0.06935552, -0.22626652, -0.15415075, -0.25295053,
#          0.1714055 , -0.23424793, -0.12966299, -0.0222102 ,  0.20323492,
#         -0.12128425, -0.034582  , -0.10561475,  0.15259167,  0.10606967,
#          0.16150786, -0.20319403, -0.26570655, -0.16422359, -0.15204657,
#          0.10043809,  0.16420289,  0.03653625, -0.20638334,  0.19689252,
#          0.11517616,  0.11488116,  0.0480626 , -0.10590487, -0.21765924,
#          0.25352753,  0.16552385,  0.12604235, -0.2833542 ,  0.26236481,
#         -0.04720876,  0.11737966,  0.25245147, -0.08913767,  0.28631281,
#          0.04077876,  0.05389826,  0.03783726, -0.12093526,  0.01215881,
#         -0.16530289,  0.00358912, -0.14945412,  0.21827361, -0.01861162,
#         -0.00366289,  0.16023002,  0.0634666 ,  0.23272887, -0.02752607,
#          0.24098295,  0.10044179,  0.10979366,  0.00047216,  0.43559369,
#          0.2706186 ,  0.20112682, -0.26191378,  0.10584906, -0.03359961]),
#  array([-0.16716883,  0.1386343 , -0.03220426,  0.08219792,  0.01873755,
#         -0.20508103,  0.00343978,  0.27934457, -0.06556199, -0.12143027,
#         -0.05202334, -0.19739772, -0.04045482,  0.09164541,  0.0793445 ,
#         -0.108259  ,  0.03052715, -0.10732729, -0.04561838, -0.25448057,
#          0.1699393 ,  0.16291971,  0.09976025, -0.07045556, -0.05574908,
#         -0.02534349, -0.20937019, -0.11961961, -0.12154644,  0.04230248,
#          0.23516141,  0.00822806,  0.03635982, -0.18327864, -0.03734769,
#          0.15247968, -0.04976507, -0.16559472, -0.11153654, -0.18927007,
#          0.12698218, -0.17028547, -0.09348737, -0.01570976,  0.15130288,
#         -0.09095661, -0.02758243, -0.07991472,  0.11338903,  0.07996863,
#          0.11719554, -0.15113776, -0.19326007, -0.11782686, -0.11149126,
#          0.07457451,  0.12205989,  0.02759978, -0.15158109,  0.14328505,
#          0.08612218,  0.0836417 ,  0.03215028, -0.07939182, -0.1606358 ,
#          0.18535176,  0.12117414,  0.09321773, -0.21215667,  0.19250409,
#         -0.03471013,  0.08823157,  0.18619679, -0.06938469,  0.21128967,
#          0.03154327,  0.04104614,  0.02935234, -0.08894843,  0.0112524 ,
#         -0.12211451,  0.00443017, -0.10957126,  0.15997172, -0.01676297,
#         -0.00392476,  0.119869  ,  0.0457054 ,  0.17377999, -0.01617026,
#          0.17627604,  0.07608448,  0.08067673,  0.00195355,  0.32111763,
#          0.20273742,  0.14880428, -0.19608568,  0.08105472, -0.02383056])]

# %% [markdown]
# ### Fit Model

# %%
model.fit(np.array(embedded_x_train), np.array(Y_train), epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5530 - loss: 0.6921
# Epoch 2/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5218 - loss: 0.6946
# Epoch 3/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5301 - loss: 0.6925
# Epoch 4/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4546 - loss: 0.6954
# Epoch 5/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5615 - loss: 0.6907
# Epoch 6/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4937 - loss: 0.6968
# Epoch 7/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4844 - loss: 0.6948
# Epoch 8/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4763 - loss: 0.6949
# Epoch 9/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4646 - loss: 0.6979
# Epoch 10/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5577 - loss: 0.6895
# Epoch 11/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4932 - loss: 0.6971
# Epoch 12/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4230 - loss: 0.6997

# %% [markdown]
# ### Function that predicts Evaluation by String

# %%
def test_string_model(input_str , model , emb_model):
    docs = tokenize_list([input_str])[0]
    print(docs)
    counter = 0
    vector = np.zeros(shape=(100,))
    avrg_vector = np.zeros(shape=(100,))
    for doc in docs:
        try:
            vector += np.array(emb_model.wv[doc])
            counter +=1

        except:
            continue

    avrg_vector = vector / counter
    
    vector_with_batch = np.expand_dims(avrg_vector, axis=0)
    
    return model.predict(vector_with_batch)

# %% [markdown]
# ### test Function

# %%
test_string_model("angela Merkel" , model , w2v_model)
# Out:
# ['angela', 'merkel']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# /tmp/ipykernel_42659/600856121.py:15: RuntimeWarning: invalid value encountered in divide
#   avrg_vector = vector / counter
# array([[nan]], dtype=float32)

# %% [markdown]
# ## LSTM Model Classification

# %% [markdown]
# ### Size of Embedding Vector in w2vmodel

# %%
EMBEDDING_DIM = 100

# %% [markdown]
# ### Embedd a whole sentence function

# %%
MAX_LENGTH = 500
def sentence_to_embedding(sentence , embedding_model):
    temp_embedding_matrix = np.zeros((MAX_LENGTH, EMBEDDING_DIM))  # Leere Matrix für Embeddings
    for i, word in enumerate(sentence[:MAX_LENGTH]):  # Maximal 5 Wörter
        if word in embedding_model.wv:
            temp_embedding_matrix[i] = embedding_model.wv[word]  # Wortvektor einfügen
    return temp_embedding_matrix

# %% [markdown]
# ### Prepare Test and Train Data

# %%
X_train_lstm = [sentence_to_embedding(x , w2v_model) for x in X_train ]
X_test_lstm = [sentence_to_embedding(x , w2v_model) for x in X_test ]

# %% [markdown]
# ### LSTM Model Architecture

# %%
#embedding_vector_features=45

ltsm_model=Sequential()

ltsm_model.add(layers.Masking(mask_value=0.0, input_shape=(MAX_LENGTH, EMBEDDING_DIM)))

ltsm_model.add(layers.LSTM(128,activation='relu',return_sequences=False))

ltsm_model.add(layers.Dropout(0.2))
ltsm_model.add(layers.Dense(1, activation="sigmoid"))
# Out:
# 56
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Compile Model

# %%
ltsm_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### Fit LSTM Model

# %%
ltsm_model.fit(np.array(X_train_lstm), np.array(Y_train).reshape(-1, 1), epochs=30, batch_size=10)
# Out:
# Epoch 1/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.5501 - loss: 0.6336
# Epoch 2/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - accuracy: 0.5512 - loss: 0.6697
# Epoch 3/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.7485 - loss: 0.5968
# Epoch 4/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 0.5640 - loss: 0.5904
# Epoch 5/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.7101 - loss: 0.6371
# Epoch 6/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.6371 - loss: 0.6142
# Epoch 7/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.6342 - loss: 0.6474
# Epoch 8/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.6063 - loss: 0.6726
# Epoch 9/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.5103 - loss: 0.6551
# Epoch 10/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.6747 - loss: 0.6475
# Epoch 11/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.6199 - loss: 0.6605
# Epoch 12/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.5946 - loss: 0.6677
# Epoch 13/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - accuracy: 0.7207 - loss: 0.6314
# Epoch 14/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.6552 - loss: 0.6335
# Epoch 15/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.7169 - loss: 0.6042
# Epoch 16/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 0.6145 - loss: 0.6254
# Epoch 17/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.8205 - loss: 0.4613
# Epoch 18/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 0.6672 - loss: 0.5165
# Epoch 19/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.6228 - loss: 0.5940
# Epoch 20/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.8245 - loss: 0.4983
# Epoch 21/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.7121 - loss: 0.5196
# Epoch 22/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 0.7264 - loss: 0.6722
# Epoch 23/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.7823 - loss: 0.5821
# Epoch 24/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.7438 - loss: 0.6180
# Epoch 25/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.7565 - loss: 0.6177
# Epoch 26/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.6937 - loss: 0.6471
# Epoch 27/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.7081 - loss: 0.6205
# Epoch 28/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.7140 - loss: 0.5958
# Epoch 29/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 0.6796 - loss: 0.6472
# Epoch 30/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 0.6791 - loss: 0.5928

# %% [markdown]
# ### Function to Predict by Sentence

# %%
def predict_sentence_ltsm(word2vec_model, sentence):
    """
    Funktion zur Vorhersage eines Satzes mit dem trainierten LSTM-Modell.
    """
    model = ltsm_model
    words = sentence.lower().split()  # Satz in Wörter umwandeln
    embedding_matrix = np.zeros((MAX_LENGTH, EMBEDDING_DIM))  # Leere Matrix für Embeddings
    
    for i, word in enumerate(words[:MAX_LENGTH]):  # Nur die ersten MAX_LENGTH Wörter nehmen
        word = word.lower()
        if word in word2vec_model.wv:
            embedding_matrix[i] = word2vec_model.wv[word]  # Wortvektor einfügen

    # In 3D-Form bringen: (1, MAX_LENGTH, EMBEDDING_DIM)
    input_data = np.expand_dims(embedding_matrix, axis=0)
    
    # Vorhersage mit Modell
    prediction = model.predict(input_data)[0][0]  # Output ist eine 2D-Matrix, daher [0][0]
    
    # In "Positiv" oder "Negativ" umwandeln
    sentiment = "Positiv" if prediction > 0.5 else "Negativ"
    print(f"Satz: '{sentence}' → {sentiment} (Score: {prediction:.4f})")

# %% [markdown]
# ### Test

# %%
predict_sentence_ltsm(w2v_model, str(df[(df["title"] == "The Ricks Must Be Crazy")]["text"]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Satz: '16    rick morty summer exit theater showcasing ball...
# Name: text, dtype: object' → Negativ (Score: 0.2231)

# %%
for title in test["title"]:
    print(predict_sentence_ltsm(w2v_model, str(df[(df["title"] == title)]["text"])))
for rating in test["evaluation"]:
    print(rating)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Satz: '70      rick morty explore " carnival nightmares " t...
# Name: text, dtype: object' → Negativ (Score: 0.0061)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Satz: '5      morty interested jessica lacks opportunity e...
# Name: text, dtype: object' → Negativ (Score: 0.3114)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Satz: '48    leaving trip smiths leave rick home alone leav...
# Name: text, dtype: object' → Negativ (Score: 0.2063)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Satz: '52    rick morty summer trip blips chitz goes awry a...
# Name: text, dtype: object' → Negativ (Score: 0.0878)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Satz: '3    episode opens rick dissecting large rat garage...
# Name: text, dtype: object' → Negativ (Score: 0.2400)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Satz: '11    episode opens time still frozen ending season ...
# Name: text, dtype: object' → Negativ (Score: 0.3208)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Satz: '16    rick morty summer exit theater showcasing ball...
# Name: text, dtype: object' → Negativ (Score: 0.2231)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Satz: '63    rick therapy dr wong gets call president curti...
# Name: text, dtype: object' → Negativ (Score: 0.0439)
# None
# 1
# 1
# 0
# 0
# 1
# 1
# 1
# 0

# %% [markdown]
# ## Regression with LSTM

# %% [markdown]
# ### Create Embedding Matrix

# %%
VOCAB_SIZE = len(w2v_model.wv.key_to_index.keys()) + 1  # +1 für Padding-Token
EMBEDDING_DIM = 100
embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_DIM))

for word in w2v_model.wv.key_to_index:
    if word in w2v_model.wv:
        embedding_matrix[w2v_model.wv.key_to_index[word]] = w2v_model.wv[word]

# %% [markdown]
# ### Model Architecture

# %%
X_train_lstm = [sentence_to_embedding(x , w2v_model) for x in X_train ]
print(len(X_train_lstm))

embedding_vector_features=45

ltsm_model_reg=Sequential()

ltsm_model_reg.add(layers.Masking(mask_value=0.0, input_shape=(MAX_LENGTH, EMBEDDING_DIM)))

ltsm_model_reg.add(layers.LSTM(128,activation='relu',return_sequences=False))

ltsm_model_reg.add(layers.Dropout(0.4))
ltsm_model_reg.add(layers.Dense(100, activation="sigmoid"))
ltsm_model_reg.add(layers.Dense(30, activation="sigmoid"))
ltsm_model_reg.add(layers.Dense(30, activation="sigmoid"))
ltsm_model_reg.add(layers.Dense(1, activation=None))

# ltsm_model.add(layers.LSTM(128,activation='relu'))

# ltsm_model.add(layers.Dropout(0.2))

# %% [markdown]
# ### Compile Model

# %%
ltsm_model_reg.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-1), metrics=["mean_squared_error"])

# %% [markdown]
# ### Fit Model

# %%
ltsm_model_reg.fit(np.array(X_train_lstm), np.array(Y_train_reg).reshape(-1, 1), epochs=15, batch_size=10)

# %% [markdown]
# ### Function to Predict Rating based on Sentence

# %%
def predict_sentence_ltsm_reg(word2vec_model, sentence):
    """
    Funktion zur Vorhersage eines Satzes mit dem trainierten LSTM-Modell.
    """
    model = ltsm_model_reg
    words = sentence.lower().split()  # Satz in Wörter umwandeln
    embedding_matrix = np.zeros((MAX_LENGTH, EMBEDDING_DIM))  # Leere Matrix für Embeddings
    
    for i, word in enumerate(words[:MAX_LENGTH]):  # Nur die ersten MAX_LENGTH Wörter nehmen
        word = word.lower()
        if word in word2vec_model.wv:
            embedding_matrix[i] = word2vec_model.wv[word]  # Wortvektor einfügen

    # In 3D-Form bringen: (1, MAX_LENGTH, EMBEDDING_DIM)
    input_data = np.expand_dims(embedding_matrix, axis=0)
    
    # Vorhersage mit Modell
    prediction = model.predict(input_data)[0][0]  # Output ist eine 2D-Matrix, daher [0][0]
    
    # In "Positiv" oder "Negativ" umwandeln
    print(f"{prediction}")

# %%
predict_sentence_ltsm_reg(w2v_model, str(df[(df["title"] == "JuRicksic Mort")]["text"]))

# %%
predict_sentence_ltsm_reg(w2v_model, "rick and morty are on an adveture")

# %%
ltsm_model_reg.evaluate(np.array(X_test_lstm) , np.array(Y_test_reg))
