# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from keras.models import Sequential
from keras import layers
import keras
# Out:
# 2025-02-14 22:26:57.887194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739568417.901728   60188 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739568417.905887   60188 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-14 22:26:57.919836: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
PATH_DESCRIPTIONS_CLEAN = "/home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/topic_modeling/data/episodes_description.csv"
PATH_IMDB_RATINGS_CLEAN = "/home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/data/episodes.json"


df_descriptions = pd.read_csv(PATH_DESCRIPTIONS_CLEAN)
df_imdb_ratings = pd.read_json(PATH_IMDB_RATINGS_CLEAN , orient="index")
df_descriptions
# Out:
#     Unnamed: 0                   title  \
# 0            0                   Pilot
# 1            1           Lawnmower Dog
# 2            2  Anatomy Park (Episode)
# 3            3  M. Night Shaym-Aliens!
# 4            4    Meeseeks and Destroy
# ..         ...                     ...
# 76          76              Mercy Kill
# 77          77             Girls Night
# 78          78                Kintsugi
# 79          79           Little Trains
# 80          80                  Heroes
#
#                                                  text
# 0   middle night obviously drunk rick bursts morty...
# 1     jerry complains family dog snuffles stupid r...
# 2   christmas jerry tries enforce idea " human hol...
# 3   episode opens rick dissecting large rat garage...
# 4   mr meeseeks existing solve beth ’s problemafte...
# ..                                                ...
# 76  planet dorian 5 supernova vance slaughtering i...
# 77  bar calypso diablo verde lady katana supernova...
# 78  " unknown planet somber alan rails puts togeth...
# 79  doom nomitron arrives destroy earth satellite ...
# 80  thanks vindicators ’ manipulations prepared re...
#
# [81 rows x 3 columns]

# %%
df_descriptions["rating"] = pd.Series(list(df_imdb_ratings["rating"]))
df = df_descriptions
df = df.dropna()
df
# Out:
#     Unnamed: 0                               title  \
# 0            0                               Pilot
# 1            1                       Lawnmower Dog
# 2            2              Anatomy Park (Episode)
# 3            3              M. Night Shaym-Aliens!
# 4            4                Meeseeks and Destroy
# ..         ...                                 ...
# 66          66               Rickfending Your Mort
# 67          67           Wet Kuat Amortican Summer
# 68          68  Rise of the Numbericons: The Movie
# 69          69                     Mort: Ragnarick
# 70          70                        Fear No Mort
#
#                                                  text  rating
# 0   middle night obviously drunk rick bursts morty...     7.9
# 1     jerry complains family dog snuffles stupid r...     8.6
# 2   christmas jerry tries enforce idea " human hol...     8.3
# 3   episode opens rick dissecting large rat garage...     8.6
# 4   mr meeseeks existing solve beth ’s problemafte...     9.0
# ..                                                ...     ...
# 66  morty finds rick drunken stupor floor garage s...     7.8
# 67  rick ’s chores ( including cleaning another " ...     6.4
# 68  episode starts exact way post credits scene " ...     4.5
# 69  jerry white void golden light appear front nan...     7.9
# 70    rick morty explore " carnival nightmares " t...     9.4
#
# [71 rows x 4 columns]

# %%
df["evaluation"] = (df["rating"] > 8.2).astype(int)
df
# Out:
# /tmp/ipykernel_60188/3675656629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["evaluation"] = (df["rating"] > 8.2).astype(int)
#     Unnamed: 0                               title  \
# 0            0                               Pilot
# 1            1                       Lawnmower Dog
# 2            2              Anatomy Park (Episode)
# 3            3              M. Night Shaym-Aliens!
# 4            4                Meeseeks and Destroy
# ..         ...                                 ...
# 66          66               Rickfending Your Mort
# 67          67           Wet Kuat Amortican Summer
# 68          68  Rise of the Numbericons: The Movie
# 69          69                     Mort: Ragnarick
# 70          70                        Fear No Mort
#
#                                                  text  rating  evaluation
# 0   middle night obviously drunk rick bursts morty...     7.9           0
# 1     jerry complains family dog snuffles stupid r...     8.6           1
# 2   christmas jerry tries enforce idea " human hol...     8.3           1
# 3   episode opens rick dissecting large rat garage...     8.6           1
# 4   mr meeseeks existing solve beth ’s problemafte...     9.0           1
# ..                                                ...     ...         ...
# 66  morty finds rick drunken stupor floor garage s...     7.8           0
# 67  rick ’s chores ( including cleaning another " ...     6.4           0
# 68  episode starts exact way post credits scene " ...     4.5           0
# 69  jerry white void golden light appear front nan...     7.9           0
# 70    rick morty explore " carnival nightmares " t...     9.4           1
#
# [71 rows x 5 columns]

# %%
#train, val, test = np.split(df.sample(frac=1), [int(0.8*len(df)), int(0.9*len(df))])
train , test = np.split(df.sample(frac=1), [int(0.8*len(df))])
len(test)
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# 15

# %%
test
# Out:
#     Unnamed: 0                            title  \
# 57          57               Full Meta Jackrick
# 62          62                 The Jerrick Trap
# 21          21       The Rickshank Rickdemption
# 44          44             Rickdependence Spray
# 35          35           Rattlestar Ricklactica
# 11          11                 A Rickle in Time
# 67          67        Wet Kuat Amortican Summer
# 65          65                     Unmortricken
# 30          30        The Rickchurian Mortydate
# 0            0                            Pilot
# 22          22            Rickmancing the Stone
# 8            8  Something Ricked This Way Comes
# 17          17    Big Trouble in Little Sanchez
# 26          26            Rest and Ricklaxation
# 64          64                    That's Amorte
#
#                                                  text  rating  evaluation
# 57  episode starts recap sequence rick suspects so...     7.8           0
# 62  rick fixing flying saucer garage jerry comes a...     7.3           0
# 21  episode starts rick family sitting booth old f...     9.6           1
# 44  beth ’s workplace morty begs hurry miss movie ...     5.7           0
# 35  getting ready adventure rick morty stop talk j...     8.8           1
# 11  episode opens time still frozen ending season ...     8.8           1
# 67  rick ’s chores ( including cleaning another " ...     6.4           0
# 65  extended flashback evil morty ’s past shown : ...     9.2           1
# 30  unknown monster attacks janitor tunnels white ...     8.2           0
# 0   middle night obviously drunk rick bursts morty...     7.9           0
# 22  jerry wearing rick morty summer fall portal ba...     8.1           0
# 8   smith family eating breakfast rick creates sma...     8.4           1
# 17  eating breakfast jerry asks children summer mo...     8.4           1
# 26  episode begins school morty hears jessica brok...     8.8           1
# 64  morty holding spaghetti.the smith family enjoy...     8.3           1

# %%
X_train = train["text"]
#X_val = val["text"]
X_test = test["text"]

Y_train = train["evaluation"]
#Y_val = val["evaluation"]
Y_test = test["evaluation"]

Y_train_reg = train["rating"] 
#Y_val_reg = val["rating"] * 100
Y_test_reg = test["rating"] 


print(Y_test_reg)
# Out:
# 57    7.8
# 62    7.3
# 21    9.6
# 44    5.7
# 35    8.8
# 11    8.8
# 67    6.4
# 65    9.2
# 30    8.2
# 0     7.9
# 22    8.1
# 8     8.4
# 17    8.4
# 26    8.8
# 64    8.3
# Name: rating, dtype: float64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

td = TfidfVectorizer(max_features = 800)
X = td.fit_transform(df["text"].values).toarray()

# %%
embedded_x_train = td.fit_transform(X_train.values).toarray()
embedded_x_test = td.fit_transform(X_test.values).toarray()
embedded_test = td.fit_transform([("Hello I am Donald J Trump" * 500)] )
embedded_test
# Out:
# <1x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

classifier = MultinomialNB()
classifier.fit(embedded_x_train, Y_train)
# Out:
# MultinomialNB()

# %%
y_pred = classifier.predict(embedded_x_test)
y_pred
# Out:
# array([1, 0, 1, 1, 1, 1, 1, 1, 0, 1, 1, 0, 0, 1, 0])

# %% [markdown]
# ## Neural Net

# %%
model = Sequential()
model.add(layers.Dense(100, input_shape=(800,) , activation='relu'))
model.add(layers.Dense(70, activation='relu'))
model.add(layers.Dense(70, activation='relu'))
model.add(layers.Dense(30, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /home/anton/Anton/Studium/DHBW /Semester_5/Text_Analysis/repo/Burg-NLP/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-02-14 22:26:59.686124: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %%
model.fit(np.array(embedded_x_train), np.array(Y_train), epochs=60, batch_size=10)
# Out:
# Epoch 1/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3607 - loss: 0.6946
# Epoch 2/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6004 - loss: 0.6927
# Epoch 3/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6224 - loss: 0.6921
# Epoch 4/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7030 - loss: 0.6911
# Epoch 5/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7467 - loss: 0.6906
# Epoch 6/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8128 - loss: 0.6888
# Epoch 7/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8828 - loss: 0.6880
# Epoch 8/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8757 - loss: 0.6875
# Epoch 9/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8903 - loss: 0.6873
# Epoch 10/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9151 - loss: 0.6858
# Epoch 11/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8662 - loss: 0.6858
# Epoch 12/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9131 - loss: 0.6847
# Epoch 13/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9144 - loss: 0.6834
# Epoch 14/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9265 - loss: 0.6821
# Epoch 15/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9428 - loss: 0.6814
# Epoch 16/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9011 - loss: 0.6801
# Epoch 17/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.6770
# Epoch 18/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.6765
# Epoch 19/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 0.6747
# Epoch 20/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9623 - loss: 0.6727
# Epoch 21/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9623 - loss: 0.6699
# Epoch 22/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.6662
# Epoch 23/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6640
# Epoch 24/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6617
# Epoch 25/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.6584
# Epoch 26/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.6555
# Epoch 27/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.6510
# Epoch 28/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6446
# Epoch 29/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6396
# Epoch 30/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6346
# Epoch 31/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6274
# Epoch 32/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.6179
# Epoch 33/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.6066
# Epoch 34/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.5940
# Epoch 35/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.5835
# Epoch 36/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.5718
# Epoch 37/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.5605
# Epoch 38/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.5400
# Epoch 39/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.5263
# Epoch 40/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.5023
# Epoch 41/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.4908
# Epoch 42/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.4625
# Epoch 43/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.4456
# Epoch 44/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.4184
# Epoch 45/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.4035
# Epoch 46/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.3713
# Epoch 47/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.3427
# Epoch 48/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.3140
# Epoch 49/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2788
# Epoch 50/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2687
# Epoch 51/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2459
# Epoch 52/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2228
# Epoch 53/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1991
# Epoch 54/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1801
# Epoch 55/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1610
# Epoch 56/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1473
# Epoch 57/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1308
# Epoch 58/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1154
# Epoch 59/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1017
# Epoch 60/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0896

# %%
test_results_nn = model.predict(embedded_x_test)
test_results_nn = [x[0] for x in test_results_nn]
test_results_nn
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [0.42754948,
#  0.36524087,
#  0.66489387,
#  0.7812821,
#  0.37806755,
#  0.76940286,
#  0.56021434,
#  0.5587071,
#  0.5447006,
#  0.6532505,
#  0.49298236,
#  0.19818756,
#  0.5159883,
#  0.71620685,
#  0.1563663]

# %%
Y_test
# Out:
# 57    0
# 62    0
# 21    1
# 44    0
# 35    1
# 11    1
# 67    0
# 65    1
# 30    0
# 0     0
# 22    0
# 8     1
# 17    1
# 26    1
# 64    1
# Name: evaluation, dtype: int64

# %%
model.predict(embedded_x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# array([[0.42754948],
#        [0.36524087],
#        [0.66489387],
#        [0.7812821 ],
#        [0.37806755],
#        [0.76940286],
#        [0.56021434],
#        [0.5587071 ],
#        [0.5447006 ],
#        [0.6532505 ],
#        [0.49298236],
#        [0.19818756],
#        [0.5159883 ],
#        [0.71620685],
#        [0.1563663 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.array(range(len(test_results_nn))) + 1

colors = ["green" if y==1 else "blue" for y in Y_test] # Green = Good Episode

plt.bar(x_axis, test_results_nn , color=colors)
plt.title('Test Evaluation LSTM')
plt.xlabel('Test')
plt.ylabel('Prediction Value')
plt.show()

# %% [markdown]
# ### Classification with Bag of Words

# %%
vect = CountVectorizer(max_features= 900)
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
#X_test_dtm.todense()[0]

# %%
from sklearn.naive_bayes import GaussianNB

gnb_model =  GaussianNB()
gnb_model.fit(X_train_dtm.toarray() , Y_train )
# Out:
# GaussianNB()

# %%
y_pred = gnb_model.predict(X_test_dtm.toarray())

# %%
Y_test
# Out:
# 57    0
# 62    0
# 21    1
# 44    0
# 35    1
# 11    1
# 67    0
# 65    1
# 30    0
# 0     0
# 22    0
# 8     1
# 17    1
# 26    1
# 64    1
# Name: evaluation, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# Konfusionsmatrix berechnen
cm = confusion_matrix(Y_test, y_pred)


# Anzeige der Konfusionsmatrix mit seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["under average","over average"], yticklabels=["under average","over average"])
plt.xlabel("Predicted Class")
plt.ylabel("Real Class")
plt.title("Konfusionsmatrix Gaussian Bayes (BOW)")
plt.show()
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.22         7
#            1       0.54      0.88      0.67         8
#
#     accuracy                           0.53        15
#    macro avg       0.52      0.51      0.44        15
# weighted avg       0.52      0.53      0.46        15

# %% [markdown]
# ### Classification TF IDF Gauss

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

td = TfidfVectorizer(max_features = 400)
X_train_tf_idf = td.fit_transform(X_train).toarray()
X_test_tf_idf = td.fit_transform(X_test).toarray()

# %%
gnb_model_tf_idf =  GaussianNB()
gnb_model_tf_idf.fit(X_train_tf_idf , Y_train )
# Out:
# GaussianNB()

# %%
y_pred = gnb_model_tf_idf.predict(X_test_tf_idf)

# %%
Y_test
# Out:
# 57    0
# 62    0
# 21    1
# 44    0
# 35    1
# 11    1
# 67    0
# 65    1
# 30    0
# 0     0
# 22    0
# 8     1
# 17    1
# 26    1
# 64    1
# Name: evaluation, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


# Konfusionsmatrix berechnen
cm = confusion_matrix(Y_test, y_pred)


# Anzeige der Konfusionsmatrix mit seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["under average","over average"], yticklabels=["under average","over average"])
plt.xlabel("Predicted Class")
plt.ylabel("Real Class")
plt.title("Konfusionsmatrix Gaussian Bayes (TF IDF)")
plt.show()
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53         7
#            1       0.57      0.50      0.53         8
#
#     accuracy                           0.53        15
#    macro avg       0.54      0.54      0.53        15
# weighted avg       0.54      0.53      0.53        15

# %%
df["len"] = [len(x) for x in df["text"]]
df.corr(numeric_only = True)
# Out:
# /tmp/ipykernel_60188/1226664471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["len"] = [len(x) for x in df["text"]]
#             Unnamed: 0    rating  evaluation       len
# Unnamed: 0    1.000000 -0.438012   -0.412393 -0.067574
# rating       -0.438012  1.000000    0.722851  0.230244
# evaluation   -0.412393  0.722851    1.000000  0.141553
# len          -0.067574  0.230244    0.141553  1.000000

# %% [markdown]
# ### Regression

# %% [markdown]
# ### TF IDF

# %%
from sklearn.linear_model import LinearRegression


reg = LinearRegression()
reg.fit(X_train_tf_idf , Y_train_reg )
Y_pred_reg = reg.predict(X_test_tf_idf)

# %%
Y_test_reg
# Out:
# 57    7.8
# 62    7.3
# 21    9.6
# 44    5.7
# 35    8.8
# 11    8.8
# 67    6.4
# 65    9.2
# 30    8.2
# 0     7.9
# 22    8.1
# 8     8.4
# 17    8.4
# 26    8.8
# 64    8.3
# Name: rating, dtype: float64

# %%
plt.plot( range(len(Y_pred_reg)),Y_pred_reg , label="Pred")
plt.plot(range(len(Y_pred_reg)), Y_test_reg , label="True")
plt.legend()

# %%
from sklearn.metrics import mean_absolute_error , explained_variance_score

# %%
mean_absolute_error(Y_test_reg ,Y_pred_reg )
# Out:
# 1.0869682811146388

# %%
explained_variance_score(Y_test_reg ,Y_pred_reg )
# Out:
# -0.32052774388119687
